# %%
from gensim.models import Word2Vec, KeyedVectors
import pandas as pd
import nltk

# %%
df = pd.read_csv("all_seasons.csv")

# %%
df.head()
# Out:
#    Unnamed: 0        player_name team_abbreviation   age  player_height  \
# 0           0      Dennis Rodman               CHI  36.0         198.12
# 1           1  Dwayne Schintzius               LAC  28.0         215.90
# 2           2       Earl Cureton               TOR  39.0         205.74
# 3           3        Ed O'Bannon               DAL  24.0         203.20
# 4           4        Ed Pinckney               MIA  34.0         205.74
#
#    player_weight                      college country draft_year draft_round  \
# 0      99.790240  Southeastern Oklahoma State     USA       1986           2
# 1     117.933920                      Florida     USA       1990           1
# 2      95.254320                Detroit Mercy     USA       1979           3
# 3     100.697424                         UCLA     USA       1995           1
# 4     108.862080                    Villanova     USA       1985           1
#
# ...

# %%
newTitles = df['college'].values

# %%
newTitles
# Out:
# array(['Southeastern Oklahoma State', 'Florida', 'Detroit Mercy', ...,
#        'Oklahoma State', 'Kansas', 'Wisconsin'], dtype=object)

# %%
#nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /Users/prudhvi/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
newsVec = [nltk.word_tokenize(college) for college in newTitles]
newsVec
# Out:
# [['Southeastern', 'Oklahoma', 'State'],
#  ['Florida'],
#  ['Detroit', 'Mercy'],
#  ['UCLA'],
#  ['Villanova'],
#  ['Illinois'],
#  ['Temple'],
#  ['Clemson'],
#  ['Washington'],
#  ['Memphis'],
#  ['Notre', 'Dame'],
#  ['Nevada-Las', 'Vegas'],
#  ['Delaware', 'State'],
#  ['Alabama'],
#  ['Wyoming'],
#  ['Pittsburgh'],
#  ['North', 'Carolina'],
#  ['Providence'],
#  ['Nebraska'],
#  ['Michigan', 'State'],
#  ['Providence'],
#  ['Mississippi', 'State'],
#  ['Nebraska'],
#  ['New', 'Orleans'],
#  ['Georgia', 'Tech'],
#  ['Temple'],
#  ['Villanova'],
#  ['La', 'Salle'],
#  ['Pacific'],
#  ['Georgia', 'Tech'],
#  ['Arkansas-Little', 'Rock'],
#  ['Illinois'],
#  ['Xavier'],
#  ['Duquesne'],
#  ['Syracuse'],
#  ['Alabama'],
#  ['Washington'],
#  ['Clemson'],
#  ['Nevada-Las', 'Vegas'],
#  ['Nevada-Las', 'Vegas'],
#  ['Providence'],
#  ['None'],
#  ['Georgia'],
#  ['UCLA'],
#  ['Georgetown'],
#  ['Notre', 'Dame'],
#  ['Northern', 'Illinois'],
#  ['Colorado'],
#  ['Connecticut'],
# ...

# %%
model = Word2Vec(newsVec,min_count = 1,vector_size=32)

# %%
model.wv.most_similar(positive=['Stanford'])
# Out:
# [('Tulane', 0.4524351954460144),
#  ('Cornell', 0.3952834904193878),
#  ('Purdue', 0.37560173869132996),
#  ('Temple', 0.3517817258834839),
#  ('Harvard', 0.32933008670806885),
#  ('Nebraska', 0.324697881937027),
#  ('Auburn', 0.31698277592658997),
#  ('Houston', 0.31412383913993835),
#  ('Auburn-Montgomery', 0.31061869859695435),
#  ('Hampton', 0.2921549379825592)]

# %%
vec = model.wv.get_vector('Lamar') - model.wv.get_vector('Xavier') + model.wv.get_vector('Alabama')

model.wv.most_similar(positive=[vec])
# Out:
# [('Alabama', 0.6007280945777893),
#  ('Lamar', 0.5104888081550598),
#  ('Hills', 0.4738744795322418),
#  ('State-San', 0.4555647075176239),
#  ('Dayton', 0.4461805522441864),
#  ('KOR', 0.4457172453403473),
#  ('Memorial', 0.41670793294906616),
#  ('PA', 0.40213125944137573),
#  ('Master', 0.39052873849868774),
#  ('Huntsville', 0.3902556896209717)]
